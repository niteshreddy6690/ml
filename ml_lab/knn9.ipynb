# %%
from sklearn import datasets
iris=datasets.load_iris()
iris_data=iris.data
iris_labels=iris.target
target_names=iris.target_names

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(iris_data,iris_labels,test_size=0.30)

from sklearn.neighbors import KNeighborsClassifier
classifier=KNeighborsClassifier(n_neighbors=5) 
classifier.fit(x_train,y_train)
y_pred=classifier.predict(x_test)

from sklearn.metrics import classification_report,confusion_matrix
from sklearn import metrics
print("accuracy=",(metrics.accuracy_score(y_test,y_pred)*100),"%")
print('Confusion matrix is as follows')
print(confusion_matrix(y_test,y_pred))
print('Accuracy Matrics')
print(classification_report(y_test,y_pred,target_names=iris.target_names))
pre_target=[target_names[i] for i in y_pred]
actual_target=[target_names[i] for i in y_test]
print("sl no","\tPredicted","\t\tActual","\t\t\tAnswer")
print("--------------------------------------------------------------------")
for i in range(0,len(pre_target)):
    print(i,":\t",pre_target[i],"\t\t",actual_target[i],"\t\t",end='')
    if(pre_target[i]==actual_target[i]):
        print("Yes")
    else:
        print("No")
# Out:
# accuracy= 97.77777777777777 %
# Confusion matrix is as follows
# [[15  0  0]
#  [ 0 15  1]
#  [ 0  0 14]]
# Accuracy Matrics
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        15
#   versicolor       1.00      0.94      0.97        16
#    virginica       0.93      1.00      0.97        14
#
#     accuracy                           0.98        45
#    macro avg       0.98      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45
#
# sl no 	Predicted 		Actual 			Answer
# --------------------------------------------------------------------
# 0 :	 virginica 		 virginica 		Yes
# 1 :	 setosa 		 setosa 		Yes
# 2 :	 virginica 		 virginica 		Yes
# 3 :	 setosa 		 setosa 		Yes
# 4 :	 versicolor 		 versicolor 		Yes
# 5 :	 versicolor 		 versicolor 		Yes
# 6 :	 setosa 		 setosa 		Yes
# 7 :	 versicolor 		 versicolor 		Yes
# 8 :	 setosa 		 setosa 		Yes
# 9 :	 versicolor 		 versicolor 		Yes
# 10 :	 versicolor 		 versicolor 		Yes
# 11 :	 virginica 		 virginica 		Yes
# 12 :	 setosa 		 setosa 		Yes
# 13 :	 setosa 		 setosa 		Yes
# 14 :	 virginica 		 virginica 		Yes
# 15 :	 setosa 		 setosa 		Yes
# 16 :	 setosa 		 setosa 		Yes
# 17 :	 setosa 		 setosa 		Yes
# 18 :	 versicolor 		 versicolor 		Yes
# 19 :	 virginica 		 versicolor 		No
# 20 :	 virginica 		 virginica 		Yes
# 21 :	 versicolor 		 versicolor 		Yes
# 22 :	 versicolor 		 versicolor 		Yes
# 23 :	 versicolor 		 versicolor 		Yes
# 24 :	 versicolor 		 versicolor 		Yes
# 25 :	 setosa 		 setosa 		Yes
# 26 :	 versicolor 		 versicolor 		Yes
# 27 :	 virginica 		 virginica 		Yes
# 28 :	 virginica 		 virginica 		Yes
# 29 :	 virginica 		 virginica 		Yes
# 30 :	 virginica 		 virginica 		Yes
# 31 :	 versicolor 		 versicolor 		Yes
# 32 :	 setosa 		 setosa 		Yes
# 33 :	 virginica 		 virginica 		Yes
# 34 :	 virginica 		 virginica 		Yes
# 35 :	 setosa 		 setosa 		Yes
# 36 :	 versicolor 		 versicolor 		Yes
# 37 :	 virginica 		 virginica 		Yes
# 38 :	 setosa 		 setosa 		Yes
# 39 :	 setosa 		 setosa 		Yes
# 40 :	 setosa 		 setosa 		Yes
# 41 :	 virginica 		 virginica 		Yes
# 42 :	 versicolor 		 versicolor 		Yes
# 43 :	 virginica 		 virginica 		Yes
# 44 :	 versicolor 		 versicolor 		Yes
